# %%
import openai
from groq import Groq
import pandas as pd
from dotenv import load_dotenv
import os

# %%
# change path for base folder
base_folder = 'D:/Projects/AI-Restaurent-Chat-bot/'
input_data_folder = base_folder+'input_data/'

# %%
# Setup the OpenAI client to use either Groq, OpenAI.com, or Ollama API
load_dotenv(override=True)
API_HOST = os.getenv("API_HOST")
API_HOST
# Out:
# 'groq'

# %%
if API_HOST == "groq":
    client = Groq(api_key=os.getenv('GROQ_API_KEY'))
    MODEL_NAME = os.getenv("GROQ_MODEL")

elif API_HOST == "ollama":
    client = openai.OpenAI(
        base_url=os.getenv("OLLAMA_ENDPOINT"),
        api_key="nokeyneeded",
    )
    MODEL_NAME = os.getenv("OLLAMA_MODEL")

elif API_HOST == "github":
    client = openai.OpenAI(base_url="https://models.inference.ai.azure.com", api_key=os.getenv("GITHUB_TOKEN"))
    MODEL_NAME = os.getenv("GITHUB_MODEL")

else:
    client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    MODEL_NAME = os.getenv("OPENAI_MODEL")

# %%
df = pd.read_csv(input_data_folder+"cakes_data.csv")

# %%
df.columns
# Out:
# Index(['id', 'name', 'minutes', 'tags', 'n_steps', 'steps', 'ingredients',
#        'n_ingredients', 'user_id', 'rating', 'review', 'rating_category',
#        'calories', 'total fat (PDV)', 'sugar (PDV)', 'sodium (PDV)',
#        'protein (PDV)', 'saturated fat (PDV)', 'carbohydrates (PDV)',
#        'calorie_status', 'price'],
#       dtype='object')

# %%
df.head(1)
# Out:
#     id                      name  minutes  \
# 0  142  almond fudge banana cake      110
#
#                                                 tags  n_steps  \
# 0  ['weeknight', 'time-to-make', 'course', 'prepa...       13
#
#                                                steps  \
# 0  ['mash bananas and set aside', 'beat sugar and...
#
#                                          ingredients  n_ingredients  user_id  \
# 0  ['dole banana', 'sugar', 'margarine', 'eggs', ...             11   914114
#
#    rating  ... rating_category calories  total fat (PDV)  sugar (PDV)  \
# 0       4  ...           tasty    224.8               14           87
#
#    sodium (PDV)  protein (PDV)  saturated fat (PDV)  carbohydrates (PDV)  \
# 0            10              7                    9                   11
#
#    calorie_status price
# 0      Low Calory    24
#
# [1 rows x 21 columns]

# %%
# Step 1: Clean 'tags', 'ingredients', and 'steps' columns by removing unwanted characters
df['tags'] = df['tags'].str.replace("[", "").replace("]", "").replace("'", "")
df['ingredients'] = df['ingredients'].str.replace("[", "").replace("]", "").replace("'", "")
df['steps'] = df['steps'].str.replace("[", "").replace("]", "").replace("'", "")

# %%
# Step 2: Handle missing values (fill with "unknown" for categorical or median for numerical)
df['calories'].fillna(df['calories'].median(), inplace=True)
df['price'].fillna(df['price'].median(), inplace=True)
df.fillna("unknown", inplace=True)
# Out:
# C:\Users\nakka\AppData\Local\Temp\ipykernel_19236\1841904137.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['calories'].fillna(df['calories'].median(), inplace=True)
# C:\Users\nakka\AppData\Local\Temp\ipykernel_19236\1841904137.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(df['price'].median(), inplace=True)

# %%
# Step 3: Optional - Drop duplicates if there are any
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#      id                        name  minutes  \
# 0   142    almond fudge banana cake      110
# 1   520              apple pie cake       40
# 2   822  heloise s cake mix cookies        8
# 3   916    momma s fair funnel cake       20
# 4  1633        mc donald s pancakes       20
#
#                                                 tags  n_steps  \
# 0  'weeknight', 'time-to-make', 'course', 'prepar...       13
# 1  '60-minutes-or-less', 'time-to-make', 'course'...        4
# 2  '15-minutes-or-less', 'time-to-make', 'course'...        4
# 3  '30-minutes-or-less', 'time-to-make', 'course'...        9
# 4  '30-minutes-or-less', 'time-to-make', 'course'...        4
#
#                                                steps  \
# 0  'mash bananas and set aside', 'beat sugar and ...
# 1  'cream butter , sugar and the egg', 'mix toget...
# 2  'mix all ingredients well to remove lumps', 's...
# 3  'beat eggs and sugar together and then add the...
# 4  'put all ingredients into a blender', 'blend o...
#
#                                          ingredients  n_ingredients  user_id  \
# 0  'dole banana', 'sugar', 'margarine', 'eggs', '...             11   914114
# 1  'sugar', 'egg', 'salt', 'butter', 'flour', 'ba...             12    22504
# 2               'cake mix', 'vegetable oil', 'eggs']              3    36327
# 3  'eggs', 'sugar', 'milk', 'flour', 'salt', 'bak...              7    13640
# 4  'carbonated lemon-lime beverage', 'egg', 'suga...              5    60908
#
#    rating  ... rating_category calories  total fat (PDV)  sugar (PDV)  \
# 0       4  ...           tasty    224.8               14           87
# 1       3  ...           so so    359.1               26          136
# 2       5  ...           tasty    137.4               11           46
# 3       5  ...           tasty    398.9                9           34
# 4       5  ...           tasty    225.6               14           39
#
#    sodium (PDV)  protein (PDV)  saturated fat (PDV)  carbohydrates (PDV)  \
# 0            10              7                    9                   11
# 1            18              7                   40                   16
# 2             6              2                    5                    5
# 3            16             27                   13                   23
# 4            16              8                   10                   10
#
#    calorie_status price
# 0      Low Calory    24
# 1      Low Calory    20
# 2      Low Calory    44
# 3      Low Calory    31
# 4      Low Calory    31
#
# [5 rows x 21 columns]

# %%
def generate_questions(row):
    prompt = f"""
    Based on the following dish information:
    
    Name: {row['name']}
    Ingredients: {row['ingredients']}
    Price: {row['price']}
    Review: {row['review']}
    Rating: {row['rating']}
    Calories:{row['calories']}
    
    Generate 5 user questions that someone might ask when ordering food from a menu.
    """
    
    response = client.chat.completions.create(
        model=MODEL_NAME,
        messages=[{"role": "system", "content": "You are a helpful assistant."},
                  {"role": "user", "content": prompt}],
        
    )
    
    return response['choices'][0]['message']['content']

# %%
# Loop through each row in the dataframe and generate questions
for index, row in df.iterrows():
    questions = generate_questions(row)
    generated_questions_list.append(questions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 3
#       1 # Loop through each row in the dataframe and generate questions
#       2 for index, row in df.iterrows():
# ----> 3     questions = generate_questions(row)
#       4     generated_questions_list.append(questions)
#
# Cell In[46], line 22, in generate_questions(row)
#       2 prompt = f"""
#       3 Based on the following dish information:
#       4
#    (...)
#      12 Generate 5 user questions that someone might ask when ordering food from a menu.
#      13 """
#      15 response = client.chat.completions.create(
#      16     model=MODEL_NAME,
#      17     messages=[{"role": "system", "content": "You are a helpful assistant."},
#      18               {"role": "user", "content": prompt}],
#      19
#      20 )
# ---> 22 return response['choices'][0]['message']['content']
#
# TypeError: 'ChatCompletion' object is not subscriptable
